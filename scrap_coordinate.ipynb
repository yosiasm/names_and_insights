# %%
import requests

# %%
url = 'https://geocode.arcgis.com/arcgis/rest/services/World/GeocodeServer/findAddressCandidates?SingleLine=Kalipare, Malang Kabupaten, Jawa Timur, IDN&f=json&outSR=%7B%22wkid%22%3A102100%7D&outFields=*&countryCode=IDN&distance=50000&location=%7B%22x%22%3A12514755.34118177%2C%22y%22%3A-914900.4495666418%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%7D%7D&maxLocations=6'
url = 'https://geocode.arcgis.com/arcgis/rest/services/World/GeocodeServer/findAddressCandidates?SingleLine=Kalipare, Malang Kabupaten, Jawa Timur, IDN&f=json&outFields=*&countryCode=IDN&distance=50000&location=%7B%22x%22%3A12514755.34118177%2C%22y%22%3A-914900.4495666418%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%7D%7D&maxLocations=6'
url = 'https://geocode.arcgis.com/arcgis/rest/services/World/GeocodeServer/findAddressCandidates?SingleLine=cibereng, terisi, indramayu, Jawa barat, IDN&f=json&outFields=*&countryCode=IDN&distance=50000&location=%7B%22x%22%3A12514755.34118177%2C%22y%22%3A-914900.4495666418%2C%22spatialReference%22%3A%7B%22wkid%22%3A102100%7D%7D&maxLocations=1'
# JAWA BARAT_INDRAMAYU_TERISI_CIBERENG
data = requests.get(url)

# %%
data.json()
# Out:
# {'spatialReference': {'wkid': 4326, 'latestWkid': 4326},
#  'candidates': [{'address': 'Cibereng, Terisi, Jawa Barat',
#    'location': {'x': 108.16669000000007, 'y': -6.454839999999933},
#    'score': 100,
#    'attributes': {'Loc_name': 'World',
#     'Status': 'M',
#     'Score': 100,
#     'Match_addr': 'Cibereng, Terisi, Jawa Barat',
#     'LongLabel': 'Cibereng, Terisi, Jawa Barat, IDN',
#     'ShortLabel': 'Cibereng',
#     'Addr_type': 'Locality',
#     'Type': 'City',
#     'PlaceName': 'Cibereng',
#     'Place_addr': 'Terisi, Jawa Barat',
#     'Phone': '',
#     'URL': '',
#     'Rank': 15,
#     'AddBldg': '',
#     'AddNum': '',
#     'AddNumFrom': '',
#     'AddNumTo': '',
#     'AddRange': '',
#     'Side': '',
#     'StPreDir': '',
#     'StPreType': '',
#     'StName': '',
#     'StType': '',
#     'StDir': '',
#     'BldgType': '',
#     'BldgName': '',
#     'LevelType': '',
#     'LevelName': '',
#     'UnitType': '',
#     'UnitName': '',
#     'SubAddr': '',
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('jabar_newcomers.csv')
df_kecamatan = pd.read_csv('kecamatan.csv')
# Out:
# C:\Users\yosia\AppData\Local\Temp\ipykernel_30452\2219118811.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('jabar_newcomers.csv')

# %%
df_kecamatan
# Out:
#       kec_code     provinsi            kabkota      kecamatan  code  desa
# 0     11.01.01         ACEH  KAB. ACEH SELATAN       Bakongan     7     7
# 1     11.01.02         ACEH  KAB. ACEH SELATAN    Kluet Utara    21    21
# 2     11.01.03         ACEH  KAB. ACEH SELATAN  Kluet Selatan    17    17
# 3     11.01.04         ACEH  KAB. ACEH SELATAN   Labuhan Haji    16    16
62: Maluku Utara
63: Papua Barat
64: Papua
65: Bengkulu
71: Gorontalo
72: Kepulauan Bangka Belitung
73: Sumsel (Sumatera Selatan)
74: Kepulauan Riau
75: Sulawesi Utara
76: Sulawesi Barat
77: Maluku Utara
78: Maluku
79: Papua Barat
80: Papua
81: Sulawesi Barat
82: Nusa Tenggara Timur
91: Aceh
94: Papua Barat
95: Kalimantan Utara

96: Kepulauan Riau

# %%
nik_prov_code = {
    "01": "11", #Daerah Istimewa Aceh
    "02": "12", #Sumatera Utara
    "03": "13", #Sumatera Barat
    "04": "14", #Riau
    "05": "15", #Jambi
    "06": "16", #Sumatera Selatan
    "07": "17", #Bengkulu
    "08": "18", #Lampung
    "09": "31", #DKI Jakarta
    "10": "32", #Jawa Barat
    "11": "33", #Jawa Tengah
    "12": "34", #Daerah Istimewa Yogyakarta
    "13": "35", #Jawa Timur
    "14": "51", #Bali
    "15": "52", #Nusa Tenggara Barat
    "16": "53", #Nusa Tenggara Timur
    "17": "61", #Kalimantan Barat
    "18": "62", #Kalimantan Tengah
    "19": "63", #Kalimantan Selatan
    "20": "64", #Kalimantan Timur
    "21": "71", #Sulawesi Utara
    "22": "72", #Sulawesi Tengah
    "23": "73", #Sulawesi Selatan
    "24": "74", #Sulawesi Tenggara
    "25": "81", #Maluku
    "26": "91", #Irian Jaya
}
def find_location(nik):
    if int(nik[0:2])!= 0 and int(nik[10:12]) <= 90 and int(nik[0:2]) < 11 :
        print(nik)
        return '{}.{}.{}'.format(nik_prov_code[nik[0:2]],nik[2:4],nik[4:6])
    else:
        return '{}.{}.{}'.format(nik[0:2],nik[2:4],nik[4:6])


df['kec_id'] = df['nik'].apply(find_location)
df
# Out:
# 020411100788****
# 095408440852****
# 012071039200****
# 015016291256****
# 030405030301****
# 030409530664****
# 080411460100****
# 016045010749****
# 040231124800****
# 040231123800****
# 032170907012****
# 031008131270****
# 031008490881****
# 095404290268****
# 010607540371****
# 021707640400****
# 043604091188****
# 032170120065****
# 083217012604****
# 027028230790****
# 021702251270****
# 090000000000****
# 095404020882****
# 070507630478****
# 095403210567****
# 095402041161****
# 095402540865****
# 032168300585****
# 032161410108****
# 095305670674****
# 095305690300****
# 095307230872****
# 061091000000****
# 040295000000****
# 060592000000****
# 022021988000****
# 020192000000****
# 070591000000****
# 050295000000****
# 010197000000****
# 010144000000****
# 020379000000****
# 021762531277****
# 066762101052****
# 066762501059****
# 066762470580****
# 066762670986****
# 095105271257****
# 012431200679****
# 017103100480****
# 070703020376****
# 070703350956****
# ...

# %%
kec_ids = df.kec_id.unique()
# df_kecamatan[~df_kecamatan['kec_code'].isin(kec_ids)]
len(kec_ids)
# Out:
# 12960

# %%
df_kecamatan_slice = df_kecamatan[df_kecamatan['kec_code'].isin(kec_ids)]
id_prov_1990 = []
for kec_id in kec_ids:
    if len(df_kecamatan[df_kecamatan['kec_code'] == kec_id]) == 0:
        print(kec_id)
        id_prov_1990.append(kec_id.split('.')[0])
set(id_prov_1990)

# len(df_kecamatan[df_kecamatan['kec_code'] == 'df'] )
# Out:
# 43.04.16
# 38.04.05
# 12.72.23
# 31.76.04
# 31.17.10
# 22.04.16
# 23.04.16
# 35.15.19
# 21.04.16
# 16.01.12
# 35.70.24
# 17.71.10
# 52.17.10
# 35.02.32
# 92.00.03
# 30.24.13
# 30.29.13
# 30.16.06
# 16.20.09
# 31.70.30
# 30.04.29
# 22.03.05
# 30.41.67
# 30.41.64
# 23.04.32
# 53.01.91
# 46.12.98
# 18.04.02
# 41.62.30
# 33.27.70
# 34.03.22
# 20.43.24
# 37.73.21
# 43.20.43
# 23.20.43
# 13.20.43
# 18.04.12
# 36.05.01
# 30.04.32
# 74.04.08
# 34.11.72
# 34.02.32
# 42.11.14
# 21.04.32
# 39.77.02
# 43.04.32
# 36.74.72
# 81.02.10
# 33.01.80
# 34.04.32
# 13.02.00
# 31.95.07
# 30.53.71
# 30.35.05
# 30.35.02
# 19.02.18
# 33.20.41
# 36.11.26
# 42.04.14
# 21.24.20
# 37.23.11
# 37.04.32
# 46.03.02
# 33.30.41
# 36.04.03
# 12.70.42
# 14.03.05
# 33.04.32
# 14.13.16
# 95.42.01
# 37.50.54
# 30.43.20
# 03.11.10
# 33.20.43
# 23.73.21
# 33.06.17
# 43.04.06
# 18.04.17
# 31.70.10
# 20.40.81
# 27.74.03
# 33.27.32
# 36.74.10
# 33.01.35
# 48.12.06
# 36.04.01
# 12.04.15
# 37.10.74
# 12.02.18
# 12.04.01
# ...

# %%
df[df['nik'] == '095404090580****']
# Out:
#                    nama               nik tempatLahir jenisKelamin tps  \
# 376534  RAHMAT SAPRUDIN  095404090580****    KUNINGAN            L   1
#
#           provinsi  kab_kota  kecamatan      desa  is_jabar    kec_id
# 376534  JAWA BARAT  KUNINGAN  SELAJAMBE  CIBERUNG     False  31.54.04

# %%
requests.get('https://kodewilayah.id/13.02.02.1036').content
# Out:
# b'<!DOCTYPE html>\n<html lang="id">\n\n<head>\n  <meta charset="UTF-8">\n  <link rel="icon"\n    href="data:image/svg+xml,&lt;svg xmlns=\'http://www.w3.org/2000/svg\' viewBox=\'0 0 100 100\'&gt;&lt;text y=\'.9em\' font-size=\'90\'&gt;\xf0\x9f\x87\xae\xf0\x9f\x87\xa9&lt;/text&gt;&lt;/svg&gt;">\n  \n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta name="description" content="Referensi lengkap nama dan kode wilayah se-Indonesia">\n  <title>Kode Wilayah Indonesia</title>\n  <script async type="module" crossorigin src="/assets/index.629e6337.js"></script>\n  <link rel="modulepreload" href="/assets/vendor.bebd6471.js">\n  <link rel="stylesheet" href="/assets/index.07d29302.css">\n</head>\n\n<body>\n  <div id="app" class="container mx-auto px-6 lg:px-8">\n    <div>\n      <div class="mt-12 md:mt-16 lg:mt-20">\n        <h1 class="text-4xl font-semibold mb-6">kodewilayah<span class="text-red-500">.id</span></h1>\n        <div>\n          <p class="mb-6 text-gr
# ...
